# %%
import numpy as np
from math import sin,cos,radians,sqrt
import matplotlib.pyplot as plt

# %%
x1 = -10
x2 = 10
y1 = -10
y2 = 10
plt.axis([x1,x2,y1,y1])
plt.axis('on')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4156\985548504.py:5: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.axis([x1,x2,y1,y1])
